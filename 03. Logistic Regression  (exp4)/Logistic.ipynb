# %% [markdown]
# **Logistic Regression:**
#
# Logistic Regression is a statistical model used in machine learning for binary classification tasks, where the goal is to predict one of two possible outcomes (e.g., yes/no, spam/not spam).

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
           'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

df = pd.read_csv(url, header=None, names=columns)

X = df.drop('Outcome', axis=1)
y = df['Outcome']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)


cm = confusion_matrix(y_test, y_pred)
print(" The confusion matrix is=")
print(cm)
print(" The confusion matrix is in the graphical form")
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()


accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# First 5 rows of the dataset:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#  The confusion matrix is=
# [[120  31]
#  [ 30  50]]
#  The confusion matrix is in the graphical form
# Accuracy: 0.74

# %% [markdown]
# # **StandardScaler**
#
# StandardScaler is a preprocessing tool in machine learning that adjusts the values of your data so that they all have a mean (average) of 0 and a standard deviation (spread) of 1.
#
# **Why Use StandardScaler?**
#
# **Equal Importance:** It ensures that all features contribute equally to the model, preventing features with larger values from dominating those with smaller values.
#
# **Improves Model Performance:** Many machine learning algorithms, like logistic regression and neural networks, perform better when the input features are on a similar scale.
#
# **Faster Convergence**: Standard scaling can help optimization algorithms converge more quickly by making the problem easier to solve.
#
# **How It Works: **
#
# **Mean = 0:** The average value of each feature is set to 0.
#
# **Standard Deviation = 1**: The spread or variability of the values is adjusted so that the distance from the mean is standardized across all features.
#
# In short, StandardScaler standardizes your data to improve the performance and reliability of your machine learning models.

# %% [markdown]
# Imagine you have different measurements like height in centimeters, weight in kilograms, and age in years. These numbers are very different in size—height might be around 170, weight around 70, and age around 30. If we directly use these numbers in a model, the model might give more importance to height just because the numbers are bigger, even though all features should be equally important.
#
# To fix this, we "scale" the numbers so that they are more alike. After scaling, each measurement will have an average value of 0 and will vary up or down from this average by roughly the same amount. This helps the model treat each feature fairly, improving its accuracy and performance.

# %% [markdown]
# # **Confusion Matrix:**
#
# A confusion matrix is a table used to evaluate the performance of a classification model. It compares the actual target values with the predictions made by the model, giving insight into how well the model is performing.
#
# **Structure of a Confusion Matrix**
#
# For a binary classification problem (where there are two classes: Positive and Negative), the confusion matrix is a 2x2 table that looks like this:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Why is a Confusion Matrix Important?**
#
# **Detailed Performance Insight:** It provides a comprehensive overview of how well your model is performing beyond simple accuracy.
#
# **Error Analysis:** Helps identify the types of errors (false positives vs. false negatives) your model is making, which is crucial for improving model performance.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load the Data from an Online Source
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
           'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# Load the dataset
df = pd.read_csv(url, header=None, names=columns)

# Display the first few rows of the dataset
print("First 5 rows of the dataset:")
print(df.head())

# Step 2: Split the Data into Features and Target
X = df.drop('Outcome', axis=1)  # Features
y = df['Outcome']               # Target

# Print feature values before scaling
print("\nFeature values before scaling:")
print(X.head())

# Print mean and standard deviation before scaling
print("\nMean and Standard Deviation before scaling:")
means_before = X.mean()
stds_before = X.std()
print("Means:")
print(means_before)
print("\nStandard Deviations:")
print(stds_before)

# Step 3: Apply Standard Scaling to the Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Create a DataFrame for the scaled features
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

# Print feature values after scaling
print("\nFeature values after scaling:")
print(X_scaled_df.head())

# Print mean and standard deviation after scaling
print("\nMean and Standard Deviation after scaling:")
means_after = X_scaled_df.mean()
stds_after = X_scaled_df.std()
print("Means:")
print(means_after)
print("\nStandard Deviations:")
print(stds_after)

# Step 4: Split the Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Step 5: Train the Logistic Regression Model
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)

# Step 6: Make Predictions
y_pred = model.predict(X_test)

# Step 7: Evaluate the Model
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Accuracy Score
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# First 5 rows of the dataset:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# Feature values before scaling:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# ...
